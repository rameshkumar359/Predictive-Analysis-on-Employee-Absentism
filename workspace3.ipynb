# %%
from module import *

# %%
model = absenteeism_model('model', 'scaler')

# %%
model.load_and_clean_data('Absenteeism_new_data.csv')

# %%
df=model.predicted_outputs()

# %%
df
# Out:
#     Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0          0       0.0         0         1            6
# 1          1       0.0         0         0            6
# 2          0       0.0         0         1            6
# 3          0       0.0         0         1            6
# 4          1       0.0         0         0            6
# 5          1       0.0         0         0            6
# 6          1       0.0         0         0            6
# 7          0       0.0         0         1            6
# 8          0       0.0         0         1            6
# 9          1       0.0         0         0            6
# 10         0       0.0         0         1            6
# 11         0       0.0         1         0            6
# 12         0       0.0         1         0            6
# 13         0       0.0         0         1            6
# 14         0       0.0         0         0            6
# 15         0       0.0         0         0            6
# ...

# %%
import pymysql

# %%
conn = pymysql.connect( 
        host='localhost', 
        user='root',  
        password = "root"
        )

# %%
cur = conn.cursor()

# %%
cur.execute('DROP DATABASE IF EXISTS predicted_outputs;')
# Out:
# 1

# %%
cur.execute('CREATE DATABASE IF NOT EXISTS predicted_outputs')
# Out:
# 1

# %%
cur.execute('USE predicted_outputs')
# Out:
# 0

# %%
cur.execute('DROP TABLE IF EXISTS predicted_outputs')
# Out:
# 0

# %%
cur.execute('CREATE TABLE predicted_outputs ( reason_1 BIT NOT NULL, reason_2 BIT NOT NULL, reason_3 BIT NOT NULL, reason_4 BIT NOT NULL, month_value INT NOT NULL, transportation_expense INT NOT NULL, age INT NOT NULL, body_mass_index INT NOT NULL, education BIT NOT NULL, children INT NOT NULL, pets INT NOT NULL, probability FLOAT NOT NULL, prediction BIT NOT NULL )')
# Out:
# 0

# %%
cur.execute('select * from predicted_outputs')
# Out:
# 0

# %%
for i in df.iterrows():
    print(i)
# Out:
# (0, Reason_1                    0.000000
# Reason_2                    0.000000
# Reason_3                    0.000000
# Reason_4                    1.000000
# Month Value                 6.000000
# Transportation Expense    179.000000
# Age                        30.000000
# Body Mass Index            19.000000
# Education                   1.000000
# Children                    0.000000
# Pet                         0.000000
# Probability                 0.122469
# Prediction                  0.000000
# Name: 0, dtype: float64)
# (1, Reason_1                    1.000000
# Reason_2                    0.000000
# Reason_3                    0.000000
# Reason_4                    0.000000
# Month Value                 6.000000
# Transportation Expense    361.000000
# Age                        28.000000
# Body Mass Index            27.000000
# Education                   0.000000
# Children                    1.000000
# Pet                         4.000000
# ...

# %%
insert_query = ""

# %%
insert_query = 'INSERT INTO predicted_outputs VALUES '

# %%
insert_query
# Out:
# 'INSERT INTO predicted_outputs VALUES '

# %%
df.shape
# Out:
# (40, 13)

# %%
for i in range(df.shape[0]):
    insert_query = insert_query + '('
    for j in range(df.shape[1]):
        insert_query = insert_query + str(df[df.columns.values[j]][i]) + ','

    insert_query = insert_query[:-1] + '), '

# %%
print(insert_query)
# Out:
